# %%
import pandas as pd

ejections = pd.read_csv("ejections.csv")

# %%
ejections['REASON'] = ejections['REASON'].str.lower()

# %%
ejections.EJECTEENAME[0]

ejectee_list = []
for i in ejections['EJECTEE'].unique():
    ejectee_list.append(i)
ejectee_list
# Out:
# ['orr-d101',
#  'tuckt103',
#  'ewinb101',
#  'raymh101',
#  'faatj101',
#  'shand101',
#  'hanln101',
#  'burno101',
#  'baldm101',
#  'hoovc101',
#  'rosec101',
#  'nichp101',
#  'mccat103',
#  'visnj101',
#  'chilc101',
#  'tebep101',
#  'welcc101',
#  'glasj101',
#  'mcgac101',
#  'davig102',
#  'wardm101',
#  'oconj104',
#  'greeb102',
#  'duffh101',
#  'reilc102',
#  'dailc101',
#  'grifs101',
#  'mctaj101',
#  'crooj101',
#  'mckee101',
#  'daile101',
#  'latha101',
#  'ryanj103',
#  'rhinb101',
#  'broud101',
#  'chame101',
#  'larkh101',
#  'milld103',
#  'comic101',
#  'crane101',
#  'doylj103',
#  'vaugf101',
#  'millj108',
#  'mcgrj101',
#  'browt102',
#  'longh101',
#  'beckj103',
#  'tierm101',
#  'mcalj102',
#  'kennb101',
#  'ansoc101',
#  'peith101',
#  'killf101',
#  'kellj106',
#  'grifc101',
#  'obrij104',
#  'farrd102',
#  'spieh101',
#  'jennh101',
#  'shocg101',
#  'schef101',
#  'mcclj801',
#  'mcdem101',
#  'mackc101',
#  'carte101',
#  'brods101',
#  'joycb101',
#  'clarb103',
#  'merrb101',
#  'tennf102',
#  'clard103',
#  'clemj101',
#  'taylj102',
#  'grifm101',
#  'clinb101',
#  'mcgud101',
#  'mcgub101',
#  'donop101',
#  'crosm101',
#  'clarf101',
#  'gradm101',
#  'lyond101',
#  'delae101',
#  'demog101',
#  'burkj101',
#  'langb102',
#  'paddd102',
#  'cunnb103',
#  'rogej102',
#  'boylj102',
#  'dougk101',
#  'warnj103',
#  'coold101',
#  'hallb101',
#  'hawlp101',
#  'gleak101',
#  'meekj101',
#  'sugdj101',
#  'powej105',
#  'stenj101',
#  'obrit101',
#  'davih101',
#  'ehrer101',
#  'dahlb102',
#  'hartb106',
#  'mercw101',
#  'dextc101',
#  'everb101',
#  'crosl101',
#  'donat101',
#  'mcgad102',
#  'dammb101',
#  'hillb102',
#  'selbk101',
#  'lachc101',
#  'greyb101',
#  'lajon101',
#  'robiw101',
#  'lochh101',
#  'holmd101',
#  'bowef102',
#  'wilsp102',
#  'dowdt101',
#  'hartf101',
#  'heide101',
#  'keelw101',
#  'crigl101',
#  'milld105',
#  'corct101',
#  'hamib101',
#  'smita105',
#  'freeb102',
#  'shecj101',
#  'magog101',
#  'mageb101',
#  'barrj103',
#  'donlm101',
#  'greed103',
#  'philb101',
#  'jonef102',
#  'irwic101',
#  'mcfae101',
#  'buelf101',
#  'burkj104',
#  'malob101',
#  'chanf101',
#  'schmc101',
#  'tayld102',
#  'shugf101',
#  'howeh101',
#  'leact101',
#  'ritcc101',
#  'collj103',
#  'gilbb103',
#  'waldi101',
#  'kittm101',
#  'mcgij101',
#  'ferrh101',
#  'calln101',
#  'wagnh101',
#  'piatw101',
#  'stahc101',
#  'dowlp101',
#  'murpe103',
#  'nancd101',
#  'hartb104',
#  'merts101',
#  'donaj103',
#  'bresr102',
#  'cougb101',
#  'katoj101',
#  'slagj102',
#  'bonnf101',
#  'browg102',
#  'bradb102',
#  'thomr101',
#  'zimmc101',
#  'wickb101',
#  'harpj102',
#  'pittt101',
#  'dolac101',
#  'kitsf101',
#  'wolvh101',
#  'dillp103',
#  'elbek101',
#  'harld101',
#  'tinkj101',
#  'conrw101',
#  'schag101',
#  'bemih101',
#  'brasr101',
#  'hempc101',
#  'jonej105',
#  'ohagh101',
#  'dooir101',
#  'smith104',
#  'tannj101',
#  'loweb101',
#  'cased101',
#  'kahom101',
#  'wallb101',
#  'hulsr101',
#  'brank101',
#  'smith110',
#  'dougp102',
#  'floot101',
#  'carrc106',
#  'rittl101',
#  'andej101',
#  'willj106',
#  'barcg101',
#  'keisb101',
#  'everj102',
#  'mathc102',
#  'farrj103',
#  'loftt101',
#  'klinj101',
#  'mullg102',
#  'hartt102',
#  'jackf101',
#  'poole101',
#  'dobbj101',
#  'jordd101',
#  'seymc101',
#  'weimj101',
#  'schmh101',
#  'abbae101',
#  'ganzj101',
#  'reidb101',
#  'mcfah102',
#  'mcfej101',
#  'barre801',
#  'donob101',
#  'isbef101',
#  'stras102',
#  'leevs101',
#  'frasc101',
#  'shayd101',
#  'dunnj102',
#  'willv101',
#  'craws101',
#  'mccom102',
#  'geiep101',
#  'huggm101',
#  'woods102',
#  'fultd101',
#  'lushj101',
#  'drill101',
#  'pattc101',
#  'marsd102',
#  'lyncm101',
#  'mcbrg101',
#  'phild101',
#  'abbof101',
#  'clymo101',
#  'jackj103',
#  'schla101',
#  'dundg101',
#  'blanc103',
#  'cassj102',
#  'scand101',
#  'hoggb101',
#  'stahj101',
#  'owenr101',
#  'steih101',
#  'jossa101',
#  'armob801',
#  'kille101',
#  'chesj101',
#  'kleir101',
#  'barrs101',
#  'bendc101',
#  'flahp101',
#  'coure101',
#  'spart101',
#  'hahnn101',
#  'rhoab101',
#  'mcfac102',
#  'browb102',
#  'tannl101',
#  'Doc Payne',
#  'overo101',
#  'morgc102',
#  'braid101',
#  'strie101',
#  'doolm101',
#  'taylj101',
#  'altrn101',
#  'shans101',
#  'armbh101',
#  'eganw101',
#  'clarw102',
#  'delaj103',
#  'mcclj101',
#  'sullb102',
#  'lewip101',
#  'oneib101',
#  'devla101',
#  'mages101',
#  'richl102',
#  'dorng101',
#  'oneij102',
#  'joned104',
#  'knigj102',
#  'waddr101',
#  'burca101',
#  'newtd101',
#  'falkc101',
#  'doylj106',
#  'haydj101',
#  'schro101',
#  'murrr103',
#  'howad102',
#  'karge101',
#  'schll101',
#  'brida101',
#  'mitcm102',
#  'clarn101',
#  'noonp101',
#  'beebf101',
#  'unglb101',
#  'armbc101',
#  'thomi101',
#  'walse101',
#  'brows103',
#  'cantj801',
#  'hught103',
#  'lobeh101',
#  'holle102',
#  'murrb801',
#  'mowrm101',
#  'bergb102',
#  'hahne101',
#  'spent101',
#  'andeg101',
#  'stora101',
#  'hannj101',
#  'fergg101',
#  'rossc101',
#  'streg101',
#  'cobbt101',
#  'morig101',
#  'doyll101',
#  'swach101',
#  'grane101',
#  'wintg101',
#  'raymb101',
#  'burcf101',
#  'snodf101',
#  'powem102',
#  'Ink Spot Erasmus',
#  'lordh101',
#  'charc101',
#  'altid101',
#  'clarj103',
#  'hofms101',
#  'Mike Martin',
#  'knabo101',
#  'grahp101',
#  'smits101',
#  'mcinm101',
#  'atz-j101',
#  'morap101',
#  'clemw101',
#  'hummj101',
#  'lenne102',
#  'bescb101',
#  'dubuj101',
#  'rothf101',
#  'sweeb102',
#  'barbj101',
#  'demmr101',
#  'tituj101',
#  'scotj104',
#  'paynf101',
#  'mcinh101',
#  'paskd101',
#  'wagnh103',
#  'thonj101',
#  'plane101',
#  'blisj101',
#  'speek101',
#  'tuckt101',
#  'lumlh101',
#  'konee101',
#  'beckb101',
#  'sweej102',
#  'papel101',
#  'mcelp101',
#  'stanj103',
#  'austj101',
#  'moore103',
#  'shead101',
#  'morel101',
#  'arelf101',
#  'marqr102',
#  'abstb101',
#  'bushd102',
#  'meyec101',
#  'wilhk101',
#  'batej101',
#  'lakef101',
#  'eastt101',
#  'blacl101',
#  'granj104',
#  'wardj102',
#  'evans101',
#  'smitt101',
#  'devoj101',
#  'barrj104',
#  'mclel101',
#  'hught107',
#  'oldrr101',
#  'clart101',
#  'knete101',
#  'smith101',
#  'beckf101',
#  'hyath101',
#  'simmh101',
#  'archj102',
#  'schmb102',
#  'killb101',
#  'egand102',
#  'warhj101',
#  'zimmh101',
#  'woodj108',
#  'beckh101',
#  'hausa101',
#  'herzb101',
#  'wolth101',
#  'lewid101',
#  'smitf106',
#  'needt101',
#  'hobld101',
#  'milld106',
#  'lelij101',
#  'collb101',
#  'bailb101',
#  'gibsg101',
#  'davib107',
#  'coulb101',
#  'fleta101',
#  'browm102',
#  'stard101',
#  'turnt105',
#  'burnb101',
#  'speat101',
#  'mckeb101',
#  'milld102',
#  'birmj101',
#  'stovg101',
#  'blaiw101',
#  'colek101',
#  'summe101',
#  'byrnb101',
#  'downt101',
#  'casej101',
#  'danib101',
#  'hartr102',
#  'willr104',
#  'colle101',
#  'doylj107',
#  'mccoa101',
#  'wille103',
#  'englc103',
#  'gowdh101',
#  'jackj101',
#  'butch101',
#  'halle101',
#  'kirkj101',
#  'tylel101',
#  'walkt101',
#  'kricp101',
#  'magel101',
#  'morgr101',
#  'groob101',
#  'cashc101',
#  'walkd102',
#  'wilsa102',
#  'fordr101',
#  'hallc103',
#  'blocb101',
#  'caldr101',
#  'oaker101',
#  'mccaa103',
#  'quinj102',
#  'chalg101',
#  'stano101',
#  'bodip101',
#  'gasph101',
#  'rehgw101',
#  'kelim101',
#  'seatt102',
#  'stepj104',
#  'eganb101',
#  'compp101',
#  'Joe Quirk',
#  'north101',
#  'smitr108',
#  'murpd106',
#  'ainse101',
#  'millw104',
#  'milac101',
#  'fishr101',
#  'mcdoe101',
#  'olsoi101',
#  'esmoj101',
#  'paddd101',
#  'rathm101',
#  'weavb101',
#  'phela101',
#  'cadyh101',
#  'vitto101',
#  'henrj101',
#  'walsj101',
#  'engej101',
#  'onslj101',
#  'covit101',
#  'bradh101',
#  'nelsr104',
#  'fisht103',
#  'whelj101',
#  'whitp102',
#  'gandc101',
#  'brena101',
#  'butla101',
#  'mcdot101',
#  'meyeb103',
#  'dealc102',
#  'mcalb101',
#  'daubj101',
#  'millo103',
#  'cutsg101',
#  'mitcr101',
#  'stenc101',
#  'schar103',
#  'shanh101',
#  'shaft102',
#  'vioxj101',
#  'catht101',
#  'johnc102',
#  'mense101',
#  'midke101',
#  'grohh101',
#  'carrb101',
#  'walkm102',
#  'johnd107',
#  'oneis101',
#  'perdh101',
#  'marsa101',
#  'salls101',
#  'mannl101',
#  'gedej101',
#  'dolac102',
#  'marar101',
#  'myerh101',
#  'carem101',
#  'ludef101',
#  'hendc101',
#  'agnes101',
#  'oconp102',
#  'acosm101',
#  'bergj103',
#  'blacd102',
#  'jackb101',
#  'zeidr101',
#  'yerks101',
#  'lewij101',
#  'robes103',
#  'fiscw101',
#  'schmb103',
#  'adamw101',
#  'kommf101',
#  'rickb101',
#  'bentr102',
#  'hochh101',
#  'bouca101',
#  'carif101',
#  'owenf101',
#  'yound104',
#  'henro101',
#  'boucm101',
#  'zinng101',
#  'willh103',
#  'mullu801',
#  'rowaj101',
#  'kavam101',
#  'gilbl101',
#  'goodw101',
#  'dougp101',
#  'tesrj101',
#  'kaufb101',
#  'textg101',
#  'connj107',
#  'booee101',
#  'laroh101',
#  'maisf101',
#  'jameb103',
#  'allen101',
#  'coumf101',
#  'wingi101',
#  'beckz101',
#  'omaro101',
#  'wistt101',
#  'hanfc101',
#  'kerrd102',
#  'mamaa101',
#  'burne101',
#  'reedm101',
#  'pearg101',
#  'griga101',
#  'kenwd101',
#  'keatr101',
#  'nunal101',
#  'vaugh101',
#  'delaf101',
#  'woodd101',
#  'finnh102',
#  'savaj101',
#  'rothb102',
#  'killr101',
#  'daric101',
#  'weilc101',
#  'flacm101',
#  'coopw101',
#  'costd101',
#  'coleb102',
#  'rowlp801',
#  'snydf101',
#  'haler101',
#  'leond102',
#  'shore101',
#  'tobij101',
#  'mollf101',
#  'dugeo101',
#  'mayee101',
#  'lavad101',
#  'barbw101',
#  'morah101',
#  'rawlj101',
#  'boonl101',
#  'mccog101',
#  'marid101',
#  'browb103',
#  'mcham101',
#  'bancd101',
#  'johne102',
#  'mclap101',
#  'mccal102',
#  'perrp101',
#  'smith107',
#  'babic101',
#  'niehb101',
#  'bluej101',
#  'goodp101',
#  'mayew101',
#  'rasmh101',
#  'smitj107',
#  'whalb101',
#  'berrc101',
#  'loudb101',
#  'fitze102',
#  'bushj102',
#  'davib104',
#  'zabez101',
#  'fostr103',
#  'rudod101',
#  'shawb102',
#  'seveh101',
#  'barne104',
#  'jacoe101',
#  'willk101',
#  'baird101',
#  'gonzm101',
#  'markc101',
#  'mogrg101',
#  'mullc101',
#  'thomp101',
#  'hincb101',
#  'corhr101',
#  'nessj101',
#  'fohll101',
#  'betzb101',
#  'merkf101',
#  'walsj108',
#  'clemc101',
#  'younr103',
#  'fourj101',
#  'chapr101',
#  'chash101',
#  'cravg101',
#  'leonj101',
#  'smitj106',
#  'warnh102',
#  'longt102',
#  'ritth101',
#  'nealg101',
#  'twomg101',
#  'tragw101',
#  'strua102',
#  'felsh101',
#  'stocm101',
#  'mitcf101',
#  'robed103',
#  'schnp101',
#  'ringj101',
#  'bagbj101',
#  'wortc101',
#  'maysc101',
#  'sotha101',
#  'ruthb101',
#  'stalg101',
#  'tonef101',
#  'sloat101',
#  'araga101',
#  'peckr101',
#  'billj103',
#  'baump101',
#  'harph101',
#  'kellj102',
#  'boect101',
#  'bezdh801',
#  'wardc102',
#  'meadl101',
#  'pitlj101',
#  'kingl103',
#  'cruiw101',
#  'Doc Woods',
#  'pippw101',
#  'murpe102',
#  'johnj107',
#  'loves101',
#  'daved101',
#  'hendj101',
#  'heilh101',
#  'wambb101',
#  'schaw101',
#  'jamic101',
#  'hornr101',
#  'grimb101',
#  'paulg102',
#  'jones104',
#  'fewsc101',
#  'dumog101',
#  'nehfa101',
#  'mccab101',
#  'coomj101',
#  'clemv101',
#  'ruetd101',
#  'piciv101',
#  'dillp101',
#  'cartp101',
#  'sislg101',
#  'rouse101',
#  'hollc101',
#  'hannt101',
#  'kerrd101',
#  'barbt101',
#  'schuf102',
#  'myerh102',
#  'sullj105',
#  'fordh101',
#  'mcquh101',
#  'huntn101',
#  'odoul101',
#  'judgj101',
#  'mchea101',
#  'Unknown fan',
#  'rixee101',
#  'scote101',
#  'elleh101',
#  'luqud101',
#  'catoh101',
#  'smite106',
#  'smitg104',
#  'shocu101',
#  'younr101',
#  'janvh101',
#  'heatc101',
#  'oneim102',
#  'may-j102',
#  'lambl101',
#  'power101',
#  'kopfl101',
#  'wittw101',
#  'lamob101',
#  'crans102',
#  'sherb101',
#  'brugf101',
#  'joneb103',
#  'meusi101',
#  'warda101',
#  'oleac101',
#  'brazf101',
#  'duncp101',
#  'willc103',
#  'sargj101',
#  'rappg101',
#  'petej102',
#  'mcmam101',
#  'leifl101',
#  'kruee101',
#  'pierb103',
#  'menom101',
#  'scotj101',
#  'perkc101',
#  'bluel101',
#  'pineb101',
#  'maisg101',
#  'hoytw101',
#  'hofmf101',
#  'mitcj101',
#  'bohns101',
#  'mcins101',
#  'daush101',
#  'oldhr101',
#  'olseo101',
#  'pillh101',
#  'kauft101',
#  'statj101',
#  'keenv101',
#  'grimc101',
#  'henlb101',
#  'clard101',
#  'falkb101',
#  'mcclh103',
#  'cunnb102',
#  'shinr101',
#  'wirtk101',
#  'robec101',
#  'collp101',
#  'hanef101',
#  'danfd101',
#  'burng102',
#  'frisf101',
#  'grift102',
#  'Dennis Farmington',
#  'carlh101',
#  'romme101',
#  'weinl101',
#  'ofarb101',
#  'kimmw101',
#  'fowlb101',
#  'ruelm101',
#  'ellef101',
#  'aldrv101',
#  'shanw103',
#  'devoa101',
#  'kolpr101',
#  'mattw103',
#  'woodl101',
#  'connj101',
#  'veacb101',
#  'glazw101',
#  'doakb101',
#  'harrb106',
#  'goslg101',
#  'fribb101',
#  'tierc101',
#  'pittp101',
#  'flagi101',
#  'ezzeh101',
#  'muelh102',
#  'bladr102',
#  'smitb110',
#  'muelw102',
#  'alexg102',
#  'osbot101',
#  'grimr103',
#  'soutb101',
#  'gerbw101',
#  'goocj101',
#  'mcnam101',
#  'macke101',
#  'barrb105',
#  'coleb101',
#  'meusb101',
#  'burkl101',
#  'ricoh101',
#  'freih101',
#  'dugaj101',
#  'stuaj101',
#  'myatg101',
#  'wrigr102',
#  'taylt102',
#  'grang102',
#  'wilsj105',
#  'robeg101',
#  'hales101',
#  'gehrl101',
#  'regot101',
#  'hooph101',
#  'schaa101',
#  'taylz101',
#  'wilth102',
#  'hainj101',
#  'klugj101',
#  'douga101',
#  'schuj101',
#  'leibn101',
#  'welcf101',
#  'mailw101',
#  'felig101',
#  'hartg103',
#  'lamab101',
#  'donop102',
#  'hubec101',
#  'yde-e101',
#  'spurf101',
#  'giarj101',
#  'hunnb101',
#  'millb110',
#  'riceh101',
#  'harpg101',
#  'coonj103',
#  'wilsh102',
#  'dykej101',
#  'marrw101',
#  'fothb101',
#  'simma101',
#  'bassj102',
#  'willo101',
#  'mcwed101',
#  'orouf101',
#  'rhynh101',
#  'metza101',
#  'gastm101',
#  'mccaj802',
#  'thomm101',
#  'sewel101',
#  'neunj101',
#  'thomf106',
#  'jonnb101',
#  'morer102',
#  'buckg101',
#  'culln102',
#  'mccaj801',
#  'trayp101',
#  'manuh101',
#  'englw101',
#  'hermb102',
#  'ferga101',
#  'butlj101',
#  'zitzb101',
#  'gallc101',
#  'gautd101',
#  'myerb103',
#  'moore102',
#  'kellg101',
#  'lazzt101',
#  'berrc103',
#  'reevb101',
#  'wests101',
#  'braxg101',
#  'burkb102',
#  'zacht101',
#  'pascb102',
#  'hemsr101',
#  'mostj101',
#  'white102',
#  'koenm101',
#  'scotp101',
#  'hursd101',
#  'melis101',
#  'cissb101',
#  'vancd101',
#  'gasta101',
#  'durol101',
#  'genej101',
#  'hargc101',
#  'purdp101',
#  'ehrhr101',
#  'schuj106',
#  'spoha101',
#  'haidh101',
#  'mcgob101',
#  'suscg102',
#  'doutt101',
#  'kellm801',
#  'moorj106',
#  'mccuh101',
#  'malop103',
#  'dickb101',
#  'mcnee101',
#  'strij101',
#  'farrd101',
#  'fishs101',
#  'davis101',
#  'lindj102',
#  'stewl101',
#  'wareb101',
#  'lopea102',
#  'rhemf101',
#  'kleic101',
#  'shotb101',
#  'blaif101',
#  'franf101',
#  'roetw101',
#  'fredj101',
#  'clarw101',
#  ...]

# %%
ejectee_dic = {}
for x in range(len(ejections)):
    ejectee_dic[x] = ejections.EJECTEENAME[x]
ejectee_dic
# Out:
# {0: 'Dave Orr',
#  1: 'Tommy Tucker',
#  2: 'Buck Ewing',
#  3: 'Buck Ewing',
#  4: 'Harry Raymond',
#  5: 'Jay Faatz',
#  6: 'Dan Shannon',
#  7: 'Ned Hanlon',
#  8: 'Oyster Burns',
#  9: 'Mark Baldwin',
#  10: 'Charlie Hoover',
#  11: 'Chief Roseman',
#  12: 'Parson Nicholson',
#  13: 'Tommy McCarthy',
#  14: 'Joe Visner',
#  15: 'Cupid Childs',
#  16: 'Patsy Tebeau',
#  17: 'Curt Welch',
#  18: 'Jack Glasscock',
#  19: 'Chippy McGarr',
#  20: 'George Davis',
#  21: 'Ned Hanlon',
#  22: 'Monte Ward',
#  23: "Jack O'Connor",
#  24: 'Curt Welch',
#  25: 'Bill Greenwood',
#  26: 'Hugh Duffy',
#  27: 'Charlie Reilly',
#  28: 'Patsy Tebeau',
#  29: 'Con Daily',
#  30: 'Sandy Griffin',
#  31: 'Oyster Burns',
#  32: 'Jim McTamany',
#  33: 'Jack Crooks',
#  34: 'Hugh Duffy',
#  35: 'Ned Hanlon',
#  36: 'Ed McKean',
#  37: 'Harry Raymond',
#  38: 'Ed Daily',
#  39: 'Arlie Latham',
#  40: 'Jack Ryan',
#  41: 'Monte Ward',
#  42: 'Buck Ewing',
#  43: 'Billy Rhines',
#  44: 'Patsy Tebeau',
#  45: 'Charlie Reilly',
#  46: 'Dan Brouthers',
#  47: 'Ice Box Chamberlain',
#  48: 'Henry Larkin',
#  49: 'Jack Crooks',
#  50: 'Doggie Miller',
#  51: 'Jack Crooks',
#  52: 'Tommy McCarthy',
#  53: 'Patsy Tebeau',
#  54: 'Charlie Comiskey',
#  55: 'Jack Crooks',
#  56: 'Ed Crane',
#  57: 'Ned Hanlon',
#  58: 'Jack Doyle',
#  59: 'Oyster Burns',
#  60: 'Farmer Vaughn',
#  61: 'Jocko Milligan',
#  62: 'Arlie Latham',
#  63: 'John McGraw',
#  64: 'Tommy McCarthy',
#  65: 'John McGraw',
#  66: 'Arlie Latham',
#  67: 'Tom Brown',
#  68: 'Patsy Tebeau',
#  69: "Jack O'Connor",
#  70: 'Hugh Duffy',
#  71: 'Tommy Tucker',
#  72: 'Charlie Comiskey',
#  73: 'Farmer Vaughn',
#  74: 'Arlie Latham',
#  75: 'Monte Ward',
#  76: 'Cupid Childs',
#  77: 'Patsy Tebeau',
#  78: 'Herman Long',
#  79: 'Doggie Miller',
#  80: 'Jake Beckley',
#  81: 'Mike Tiernan',
#  82: 'Patsy Tebeau',
#  83: 'Jake Beckley',
#  84: 'Jake Beckley',
#  85: 'Arlie Latham',
#  86: 'Jimmy McAleer',
#  87: 'Tommy Tucker',
#  88: 'Brickyard Kennedy',
#  89: 'Patsy Tebeau',
#  90: 'Cap Anson',
#  91: 'Arlie Latham',
#  92: "Jack O'Connor",
#  93: 'Heinie Peitz',
#  94: 'Jack Doyle',
#  95: 'Frank Killen',
#  96: 'Joe Kelley',
#  97: 'John McGraw',
#  98: 'Joe Kelley',
#  99: 'Clark Griffith',
#  100: 'Farmer Vaughn',
#  101: "John O'Brien",
#  102: 'Duke Farrell',
#  103: 'Tommy McCarthy',
#  104: 'Harry Spies',
#  105: 'John McGraw',
#  106: 'Hughie Jennings',
#  107: 'George Shoch',
#  108: 'Frank Scheibeck',
#  109: 'Jack Doyle',
#  110: 'John McCloskey',
#  111: 'John McCloskey',
#  112: 'Mike McDermott',
#  113: 'Connie Mack',
#  114: 'Patsy Tebeau',
#  115: 'Joe Kelley',
#  116: 'Ed Cartwright',
#  117: 'Steve Brodie',
#  118: "John O'Brien",
#  119: 'Bill Joyce',
#  120: 'Patsy Tebeau',
#  121: 'Patsy Tebeau',
#  122: 'Doggie Miller',
#  123: 'Joe Kelley',
#  124: 'Patsy Tebeau',
#  125: 'Boileryard Clarke',
#  126: 'Bill Merritt',
#  127: 'Fred Tenney',
#  128: 'Dad Clarke',
#  129: 'Jack Clements',
#  130: 'Jack Taylor',
#  131: 'Farmer Vaughn',
#  132: "John O'Brien",
#  133: 'Steve Brodie',
#  134: 'Mike Griffin',
#  135: 'Billy Clingman',
#  136: 'Deacon McGuire',
#  137: 'Frank Killen',
#  138: 'Bill McGunnigle',
#  139: 'Patsy Donovan',
#  140: 'Monte Cross',
#  141: 'Fred Clarke',
#  142: 'Patsy Tebeau',
#  143: 'Hughie Jennings',
#  144: 'Monte Cross',
#  145: 'Bill Joyce',
#  146: 'Mike Grady',
#  147: 'Cap Anson',
#  148: 'John McGraw',
#  149: 'Denny Lyons',
#  150: 'Ed Delahanty',
#  151: 'Gene DeMontreville',
#  152: 'Mike Grady',
#  153: 'Jack Taylor',
#  154: 'Jesse Burkett',
#  155: "Jack O'Connor",
#  156: 'George Davis',
#  157: 'Jack Doyle',
#  158: 'Mike Griffin',
#  159: 'Bill Joyce',
#  160: "John O'Brien",
#  161: 'John McGraw',
#  162: 'John McGraw',
#  163: 'Bill Lange',
#  164: "John O'Brien",
#  165: 'Hughie Jennings',
#  166: 'Joe Kelley',
#  167: 'Patsy Donovan',
#  168: 'Frank Killen',
#  169: 'Dick Padden',
#  170: 'Bert Cunningham',
#  171: 'Jim Rogers',
#  172: 'Patsy Donovan',
#  173: 'Monte Cross',
#  174: 'Charlie Reilly',
#  175: 'Monte Cross',
#  176: 'Cap Anson',
#  177: 'Jack Boyle',
#  178: 'Joe Kelley',
#  179: 'Klondike Douglass',
#  180: 'Heinie Peitz',
#  181: 'Jack Warner',
#  182: 'Hugh Duffy',
#  183: 'Cap Anson',
#  184: 'Jake Beckley',
#  185: 'Jack Boyle',
#  186: 'Duff Cooley',
#  187: 'Mike Grady',
#  188: 'Fred Clarke',
#  189: 'George Davis',
#  190: 'Tom Brown',
#  191: 'Bill Hallman',
#  192: 'Pink Hawley',
#  193: 'Kid Gleason',
#  194: 'Jouett Meekin',
#  195: 'Joe Sugden',
#  196: 'Jack Powell',
#  197: 'Boileryard Clarke',
#  198: 'Jake Stenzel',
#  199: 'Jesse Burkett',
#  200: 'Jesse Burkett',
#  201: 'Jack Doyle',
#  202: 'Boileryard Clarke',
#  203: 'Joe Kelley',
#  204: "Tom O'Brien",
#  205: 'Mike Grady',
#  206: 'Harry Davis',
#  207: 'Red Ehret',
#  208: 'Heinie Peitz',
#  209: 'Duff Cooley',
#  210: 'Billy Clingman',
#  211: 'Bill Dahlen',
#  212: 'Jack Warner',
#  213: 'Monte Cross',
#  214: 'Bill Hart',
#  215: 'Deacon McGuire',
#  216: 'Cap Anson',
#  217: 'Win Mercer',
#  218: 'Patsy Tebeau',
#  219: 'Boileryard Clarke',
#  220: 'Charlie Dexter',
#  221: 'Jack Warner',
#  222: 'Steve Brodie',
#  223: 'Pink Hawley',
#  224: 'Dick Padden',
#  225: 'Win Mercer',
#  226: 'Pink Hawley',
#  227: 'Monte Cross',
#  228: 'Joe Kelley',
#  229: 'Cap Anson',
#  230: 'Kid Gleason',
#  231: 'Bill Everitt',
#  232: 'Fred Clarke',
#  233: 'Dick Padden',
#  234: 'Charlie Dexter',
#  235: 'Tom Brown',
#  236: 'Lave Cross',
#  237: 'Bill Hallman',
#  238: 'Patsy Tebeau',
#  239: 'Mike Grady',
#  240: 'Bill Dahlen',
#  241: 'Bill Lange',
#  242: 'Clark Griffith',
#  243: 'Mike Grady',
#  244: 'Patsy Tebeau',
#  245: 'Bill Everitt',
#  246: 'Tim Donahue',
#  247: 'Bill Joyce',
#  248: 'Mike Grady',
#  249: 'John McGraw',
#  250: 'Joe Kelley',
#  251: 'Dan McGann',
#  252: 'Jesse Burkett',
#  253: 'Charlie Dexter',
#  254: 'Steve Brodie',
#  255: 'Bill Joyce',
#  256: 'Jack Warner',
#  257: 'Jack Taylor',
#  258: 'Cap Anson',
#  259: 'Hugh Duffy',
#  260: 'Herman Long',
#  261: 'John McGraw',
#  262: 'Jack Warner',
#  263: 'Bill Dahlen',
#  264: 'Kid Gleason',
#  265: 'Bill Dammann',
#  266: 'Bill Hill',
#  267: 'Buck Ewing',
#  268: 'Joe Kelley',
#  269: 'Bill Joyce',
#  270: 'Bill Dahlen',
#  271: 'Joe Kelley',
#  272: 'Hughie Jennings',
#  273: 'Cupid Childs',
#  274: 'Kip Selbach',
#  275: 'Mike Grady',
#  276: 'Mike Grady',
#  277: 'Bill Dahlen',
#  278: 'Bill Dahlen',
#  279: 'Clark Griffith',
#  280: 'Tommy Tucker',
#  281: 'Fred Clarke',
#  282: 'Charlie Dexter',
#  283: 'Candy LaChance',
#  284: 'Frank Killen',
#  285: 'Joe Kelley',
#  286: 'Patsy Tebeau',
#  287: 'Bill Gray',
#  288: 'John McGraw',
#  289: 'Bill Everitt',
#  290: 'Patsy Tebeau',
#  291: 'Farmer Vaughn',
#  292: 'Jack Warner',
#  293: 'Bill Joyce',
#  294: 'Hugh Duffy',
#  295: 'Joe Kelley',
#  296: 'John McGraw',
#  297: 'Bill Hill',
#  298: 'Jack Warner',
#  299: 'Nap Lajoie',
#  300: 'Bill Dahlen',
#  301: 'Jake Stenzel',
#  302: 'Mike Griffin',
#  303: 'Clark Griffith',
#  304: 'Wilbert Robinson',
#  305: 'Harry Lochhead',
#  306: 'Fred Clarke',
#  307: 'Ducky Holmes',
#  308: 'Frank Bowerman',
#  309: "Jack O'Connor",
#  310: 'Lave Cross',
#  311: 'Kid Gleason',
#  312: 'Joe Kelley',
#  313: 'Klondike Douglass',
#  314: 'Parke Wilson',
#  315: 'Joe Kelley',
#  316: 'Tommy Dowd',
#  317: 'Lave Cross',
#  318: 'Harry Lochhead',
#  319: 'Fred Hartman',
#  320: 'John McGraw',
#  321: 'Clark Griffith',
#  322: 'Emmet Heidrick',
#  323: 'Dick Padden',
#  324: 'Kid Gleason',
#  325: 'Jack Warner',
#  326: 'Parke Wilson',
#  327: "John O'Brien",
#  328: "John O'Brien",
#  329: 'Dick Padden',
#  330: 'Tommy Tucker',
#  331: 'Bill Dahlen',
#  332: 'Willie Keeler',
#  333: 'John McGraw',
#  334: 'Bill Dahlen',
#  335: 'Lou Criger',
#  336: 'Dusty Miller',
#  337: 'Duff Cooley',
#  338: 'John McGraw',
#  339: 'Tommy Corcoran',
#  340: 'John McGraw',
#  341: 'Jack Doyle',
#  342: 'Cupid Childs',
#  343: 'Patsy Tebeau',
#  344: 'Jesse Burkett',
#  345: 'Billy Hamilton',
#  346: 'Tim Donahue',
#  347: 'Bill Everitt',
#  348: 'Dan McGann',
#  349: 'Dick Padden',
#  350: 'John McGraw',
#  351: 'Clark Griffith',
#  352: 'Aleck Smith',
#  353: 'Fred Clarke',
#  354: 'Buck Freeman',
#  355: 'Jimmy Sheckard',
#  356: 'Heinie Peitz',
#  357: 'Aleck Smith',
#  358: 'Billy Clingman',
#  359: 'Dan McGann',
#  360: 'Jesse Burkett',
#  361: 'Buck Freeman',
#  362: 'Dan McGann',
#  363: 'Bert Cunningham',
#  364: 'Fred Clarke',
#  365: 'George Magoon',
#  366: 'Bill Magee',
#  367: 'Jack Doyle',
#  368: 'Ed Delahanty',
#  369: 'Win Mercer',
#  370: 'Candy LaChance',
#  371: 'Aleck Smith',
#  372: 'Bill Magee',
#  373: 'Jimmy Sheckard',
#  374: 'Bill Everitt',
#  375: 'Mike Grady',
#  376: 'Bill Dahlen',
#  377: 'Ed Delahanty',
#  378: 'Pink Hawley',
#  379: 'Kip Selbach',
#  380: 'John McGraw',
#  381: 'Jimmy Barrett',
#  382: 'Jesse Burkett',
#  383: 'Mike Donlin',
#  384: 'Mike Grady',
#  385: 'Jack Doyle',
#  386: 'Monte Cross',
#  387: 'Joe Kelley',
#  388: 'Brickyard Kennedy',
#  389: 'Duff Cooley',
#  390: 'Joe Kelley',
#  391: 'Danny Green',
#  392: 'John McGraw',
#  393: 'Charlie Dexter',
#  394: 'George Davis',
#  395: 'Kid Gleason',
#  396: 'Bill Phillips',
#  397: 'Fielder Jones',
#  398: 'Jake Beckley',
#  399: 'Charlie Irwin',
#  400: 'Jesse Burkett',
#  401: 'John McGraw',
#  402: 'John McGraw',
#  403: 'Wilbert Robinson',
#  404: 'Bill Dahlen',
#  405: 'Pink Hawley',
#  406: 'Ed McFarland',
#  407: 'George Davis',
#  408: 'Joe Kelley',
#  409: 'Joe Kelley',
#  410: 'Bill Dahlen',
#  411: 'Fred Tenney',
#  412: 'Bill Everitt',
#  413: 'George Davis',
#  414: 'Aleck Smith',
#  415: 'Fritz Buelow',
#  416: 'Jimmy Burke',
#  417: 'Billy Maloney',
#  418: 'Clark Griffith',
#  419: 'Frank Chance',
#  420: 'Jack Doyle',
#  421: 'John McGraw',
#  422: 'Crazy Schmit',
#  423: 'Clark Griffith',
#  424: 'Candy LaChance',
#  425: 'Nap Lajoie',
#  426: 'Hugh Duffy',
#  427: 'Buck Freeman',
#  428: 'Joe Kelley',
#  429: 'John McGraw',
#  430: 'Hugh Duffy',
#  431: 'George Davis',
#  432: 'Dummy Taylor',
#  433: 'Jack Warner',
#  434: 'Mike Grady',
#  435: 'John McGraw',
#  436: 'Frank Shugart',
#  437: 'Bill Everitt',
#  438: 'Harry Howell',
#  439: 'Wilbert Robinson',
#  440: 'Tommy Leach',
#  441: 'Claude Ritchey',
#  442: 'Jimmy Collins',
#  443: 'Buck Freeman',
#  444: 'Jimmy Sheckard',
#  445: 'Billy Gilbert',
#  446: 'Irv Waldron',
#  447: 'Clark Griffith',
#  448: 'Bill Dahlen',
#  449: 'Deacon McGuire',
#  450: 'Malachi Kittridge',
#  451: 'Joe McGinnity',
#  452: 'Danny Green',
#  453: 'Joe McGinnity',
#  454: 'Buck Freeman',
#  455: 'Danny Green',
#  456: 'Jack Warner',
#  457: 'Hobe Ferris',
#  458: 'Clark Griffith',
#  459: 'Nixey Callahan',
#  460: 'Bill Everitt',
#  461: 'Bill Everitt',
#  462: 'Honus Wagner',
#  463: 'Buck Freeman',
#  464: 'Lave Cross',
#  465: 'Wiley Piatt',
#  466: 'Chick Stahl',
#  467: 'Jesse Burkett',
#  468: 'George Davis',
#  469: 'Frank Chance',
#  470: 'Charlie Dexter',
#  471: 'Buck Freeman',
#  472: 'Pete Dowling',
#  473: 'Ducky Holmes',
#  474: 'Honus Wagner',
#  475: 'Boileryard Clarke',
#  476: 'Ed Murphy',
#  477: 'Kid Nance',
#  478: 'Clark Griffith',
#  479: 'Fritz Buelow',
#  480: 'Jimmy Hart',
#  481: 'Kip Selbach',
#  482: 'Hugh Duffy',
#  483: 'Clark Griffith',
#  484: 'Sam Mertes',
#  485: 'Fritz Buelow',
#  486: 'Fred Hartman',
#  487: 'Clark Griffith',
#  488: 'Nap Lajoie',
#  489: 'John McGraw',
#  490: 'Jiggs Donahue',
#  491: 'Roger Bresnahan',
#  492: 'Joe McGinnity',
#  493: 'Jimmy Burke',
#  494: 'Bill Coughlin',
#  495: 'Joe McGinnity',
#  496: 'Jack Katoll',
#  497: 'Frank Shugart',
#  498: 'Jimmy Slagle',
#  499: "Jack O'Connor",
#  500: 'Tommy Leach',
#  501: 'Emmet Heidrick',
#  502: 'Sam Mertes',
#  503: 'John McGraw',
#  504: 'Frank Chance',
#  505: 'Jack Doyle',
#  506: 'Frank Bonner',
#  507: 'Fritz Buelow',
#  508: 'Jesse Burkett',
#  509: 'Dick Padden',
#  510: 'John McGraw',
#  511: 'Joe Kelley',
#  512: 'Clark Griffith',
#  513: 'George Browne',
#  514: 'Tommy Leach',
#  515: 'Frank Bonner',
#  516: 'George Magoon',
#  517: 'Jimmy Sheckard',
#  518: 'Bill Bradley',
#  519: 'Monte Cross',
#  520: 'Willie Keeler',
#  521: 'Roy Thomas',
#  522: 'Clark Griffith',
#  523: 'Bill Dahlen',
#  524: 'Chief Zimmer',
#  525: 'Klondike Douglass',
#  526: 'Fred Tenney',
#  527: 'Fred Clarke',
#  528: 'Hobe Ferris',
#  529: 'Dick Padden',
#  530: 'Bill Dahlen',
#  531: 'Jimmy Sheckard',
#  532: 'Bob Wicker',
#  533: 'Joe Kelley',
#  534: 'Sam Mertes',
#  535: 'Dummy Taylor',
#  536: 'John McGraw',
#  537: 'Joe Kelley',
#  538: 'Roger Bresnahan',
#  539: 'Clark Griffith',
#  540: 'Jack Harper',
#  541: 'Togie Pittinger',
#  542: 'Jimmy Collins',
#  543: 'Ed Delahanty',
#  544: 'Cozy Dolan',
#  545: 'Dick Padden',
#  546: 'Frank Kitson',
#  547: 'Roger Bresnahan',
#  548: 'Harry Wolverton',
#  549: 'Joe Sugden',
#  550: 'Pop Dillon',
#  551: 'Kid Elberfeld',
#  552: 'Dick Harley',
#  553: 'Joe Tinker',
#  554: 'Wid Conroy',
#  555: 'Fritz Buelow',
#  556: 'Jimmy Collins',
#  557: 'George Browne',
#  558: 'John McGraw',
#  559: 'Jesse Burkett',
#  560: 'Nap Lajoie',
#  561: 'Germany Schaefer',
#  562: 'Kid Gleason',
#  563: 'Billy Gilbert',
#  564: 'Danny Green',
#  565: 'Dick Padden',
#  566: 'Harry Davis',
#  567: 'Clark Griffith',
#  568: 'Harry Bemis',
#  569: 'Clark Griffith',
#  570: 'Jesse Burkett',
#  571: 'Roy Brashear',
#  572: 'Billy Gilbert',
#  573: 'Joe Kelley',
#  574: 'Charlie Hemphill',
#  575: 'Dick Padden',
#  576: 'Jim Jones',
#  577: "Hal O'Hagan",
#  578: 'Honus Wagner',
#  579: 'Nap Lajoie',
#  580: 'Tommy Leach',
#  581: 'Aleck Smith',
#  582: 'Jim Jones',
#  583: 'Red Dooin',
#  584: 'Harry Smith',
#  585: 'Jimmy Collins',
#  586: 'Jesse Tannehill',
#  587: 'Kid Elberfeld',
#  588: 'Bobby Lowe',
#  589: 'Fred Tenney',
#  590: 'Fred Clarke',
#  591: 'Tommy Corcoran',
#  592: 'Clark Griffith',
#  593: 'Doc Casey',
#  594: 'Mike Kahoe',
#  595: 'Doc Casey',
#  596: 'Clark Griffith',
#  597: 'Dick Harley',
#  598: 'Jimmy Sheckard',
#  599: 'Bobby Wallace',
#  600: 'Gene DeMontreville',
#  601: 'Honus Wagner',
#  602: 'Lou Criger',
#  603: 'Chick Stahl',
#  604: 'George Davis',
#  605: 'Clark Griffith',
#  606: 'Billy Maloney',
#  607: 'Rudy Hulswitt',
#  608: 'Billy Gilbert',
#  609: 'Fred Tenney',
#  610: 'Kitty Bransfield',
#  611: 'Wid Conroy',
#  612: 'Heinie Smith',
#  613: 'Chick Stahl',
#  614: 'Patsy Dougherty',
#  615: 'Fielder Jones',
#  616: 'Fred Tenney',
#  617: 'Togie Pittinger',
#  618: 'Jesse Burkett',
#  619: 'Danny Green',
#  620: 'Mike Donlin',
#  621: 'Tim Flood',
#  622: 'Roger Bresnahan',
#  623: 'Joe Kelley',
#  624: 'Roger Bresnahan',
#  625: 'Joe McGinnity',
#  626: 'Fred Tenney',
#  627: 'Jimmy Sheckard',
#  628: 'Red Dooin',
#  629: 'Jack Warner',
#  630: 'George Magoon',
#  631: 'Charlie Carr',
#  632: 'Dummy Taylor',
#  633: 'Tim Flood',
#  634: 'Lew Ritter',
#  635: 'Charlie Hemphill',
#  636: 'Roger Bresnahan',
#  637: 'John Anderson',
#  638: 'Emmet Heidrick',
#  639: 'Clark Griffith',
#  640: "Jack O'Connor",
#  641: 'Jack Doyle',
#  642: 'Bill Bradley',
#  643: 'Joe McGinnity',
#  644: 'Honus Wagner',
#  645: 'Frank Bonner',
#  646: 'Jesse Tannehill',
#  647: 'Jimmy Williams',
#  648: 'Jake Beckley',
#  649: 'Nap Lajoie',
#  650: 'George Barclay',
#  651: 'Joe Kelley',
#  652: 'Bill Hallman',
#  653: 'Bill Keister',
#  654: 'Jack Doyle',
#  655: 'Frank Chance',
#  656: 'Heinie Smith',
#  657: 'Jimmy Collins',
#  658: 'Heinie Peitz',
#  659: 'Joe Kelley',
#  660: 'John McGraw',
#  661: 'Tommy Leach',
#  662: 'Joe Kelley',
#  663: 'Lew Ritter',
#  664: 'Joe Kelley',
#  665: 'Heinie Peitz',
#  666: 'Fritz Buelow',
#  667: 'Patsy Donovan',
#  668: 'Johnny Evers',
#  669: 'Frank Chance',
#  670: 'Emmet Heidrick',
#  671: 'Jack Powell',
#  672: "Jack O'Connor",
#  673: 'Frank Bowerman',
#  674: 'Christy Mathewson',
#  675: 'Jesse Tannehill',
#  676: 'Dan McGann',
#  677: 'John McGraw',
#  678: 'Roger Bresnahan',
#  679: 'Billy Clingman',
#  680: 'Patsy Dougherty',
#  681: 'John Farrell',
#  682: 'Jesse Burkett',
#  683: 'Tom Loftus',
#  684: 'Johnny Kling',
#  685: 'Joe Kelley',
#  686: 'Jimmy Sheckard',
#  687: 'George Mullin',
#  688: 'Topsy Hartsel',
#  689: 'Fred Jacklitsch',
#  690: 'Joe Kelley',
#  691: 'Ed Poole',
#  692: 'Heinie Peitz',
#  693: 'Sam Mertes',
#  694: 'Lew Ritter',
#  695: 'Lou Criger',
#  696: 'Frank Chance',
#  697: 'Nap Lajoie',
#  698: 'John Dobbs',
#  699: 'Dutch Jordan',
#  700: 'Heinie Peitz',
#  701: 'Cy Seymour',
#  702: 'Tim Flood',
#  703: 'Danny Green',
#  704: 'Jake Weimer',
#  705: 'Fritz Buelow',
#  706: 'Heinie Peitz',
#  707: 'Bill Coughlin',
#  708: 'Kip Selbach',
#  709: "Jack O'Connor",
#  710: 'Ducky Holmes',
#  711: 'Red Dooin',
#  712: 'George Magoon',
#  713: 'Harry Wolverton',
#  714: 'Billy Gilbert',
#  715: 'Kid Gleason',
#  716: "Jack O'Connor",
#  717: 'Honus Wagner',
#  718: 'Danny Green',
#  719: 'Joe Tinker',
#  720: 'Henry Schmidt',
#  721: 'Roger Bresnahan',
#  722: 'Frank Chance',
#  723: 'Ed Abbaticchio',
#  724: 'Nixey Callahan',
#  725: 'John Ganzel',
#  726: 'Billy Gilbert',
#  727: 'John McGraw',
#  728: 'Billy Gilbert',
#  729: 'Rudy Hulswitt',
#  730: 'Bill Bradley',
#  731: 'Jack Powell',
#  732: 'Mike Donlin',
#  733: 'Kid Elberfeld',
#  734: 'Jack Warner',
#  735: 'Frank Bowerman',
#  736: 'Malachi Kittridge',
#  737: 'Buck Freeman',
#  738: 'Bill Reidy',
#  739: 'Joe Tinker',
#  740: 'Herm McFarland',
#  741: 'Bill Dahlen',
#  742: 'Charlie Carr',
#  743: 'John McGraw',
#  744: 'Cy Seymour',
#  745: 'Red Dooin',
#  746: 'Rudy Hulswitt',
#  747: 'Jack McFetridge',
#  748: 'Jimmy Sheckard',
#  749: 'Ed Barrow',
#  750: 'Bill Donovan',
#  751: 'Jack Doyle',
#  752: 'John Ganzel',
#  753: 'Jesse Burkett',
#  754: 'Harry Smith',
#  755: 'Frank Isbell',
#  756: 'Sammy Strang',
#  757: 'Kid Elberfeld',
#  758: 'Red Dooin',
#  759: 'Heinie Peitz',
#  760: 'Johnny Evers',
#  761: 'Joe Kelley',
#  762: 'Heinie Peitz',
#  763: 'Harry Smith',
#  764: 'Dick Padden',
#  765: 'Sam Leever',
#  766: 'Joe Kelley',
#  767: 'John Farrell',
#  768: 'Red Dooin',
#  769: 'Jesse Burkett',
#  770: 'Joe Sugden',
#  771: 'Pop Dillon',
#  772: 'Jack Warner',
#  773: 'Chick Fraser',
#  774: 'Bill Dahlen',
#  775: 'Jake Weimer',
#  776: 'Hugh Duffy',
#  777: 'John McGraw',
#  778: 'Danny Green',
#  779: 'Joe Kelley',
#  780: 'Sam Mertes',
#  781: 'John Dobbs',
#  782: 'Dutch Jordan',
#  783: 'Jack Warner',
#  784: 'Danny Shay',
#  785: 'Nap Lajoie',
#  786: 'Jake Beckley',
#  787: 'Dan McGann',
#  788: 'John McGraw',
#  789: 'Bill Coughlin',
#  790: 'Harry Wolverton',
#  791: 'Jake Beckley',
#  792: 'Danny Shay',
#  793: 'Mike Donlin',
#  794: 'Jack Dunn',
#  795: 'John McGraw',
#  796: 'Sam Mertes',
#  797: 'Dummy Taylor',
#  798: 'Vic Willis',
#  799: 'Sam Crawford',
#  800: 'Kid Gleason',
#  801: 'Fred Clarke',
#  802: 'Danny Shay',
#  803: 'Red Dooin',
#  804: 'Pop Dillon',
#  805: 'Red Dooin',
#  806: 'Dick Padden',
#  807: 'Mike McCormack',
#  808: 'Dan McGann',
#  809: 'Fielder Jones',
#  810: 'John Dobbs',
#  811: 'Rudy Hulswitt',
#  812: 'Harry Davis',
#  813: 'Phil Geier',
#  814: 'John McGraw',
#  815: 'Tommy Corcoran',
#  816: 'Roger Bresnahan',
#  817: 'Joe Kelley',
#  818: 'Kid Gleason',
#  819: 'George Mullin',
#  820: 'Bobby Lowe',
#  821: 'Bill Donovan',
#  822: 'Red Dooin',
#  823: 'Jack Doyle',
#  824: 'Charlie Hemphill',
#  825: 'Frank Chance',
#  826: 'Pop Dillon',
#  827: 'Sammy Strang',
#  828: 'Bill Dahlen',
#  829: 'Fielder Jones',
#  830: 'Miller Huggins',
#  831: 'Joe Kelley',
#  832: 'Cy Seymour',
#  833: 'Sam Woodruff',
#  834: 'George Davis',
#  835: 'Dave Fultz',
#  836: 'Clark Griffith',
#  837: 'Danny Shay',
#  838: 'Jack Powell',
#  839: 'Jimmy Williams',
#  840: 'Mike Grady',
#  841: 'Roger Bresnahan',
#  842: 'Joe Kelley',
#  843: 'Dan McGann',
#  844: 'John McGraw',
#  845: 'Jack Harper',
#  846: 'Frank Bowerman',
#  847: 'Danny Green',
#  848: 'Joe McGinnity',
#  849: 'Honus Wagner',
#  850: 'Cozy Dolan',
#  851: 'Frank Bowerman',
#  852: 'Joe McGinnity',
#  853: 'Fred Tenney',
#  854: 'Johnny Lush',
#  855: 'Nap Lajoie',
#  856: 'Bill Bradley',
#  857: 'Johnny Evers',
#  858: 'Jake Weimer',
#  859: 'John McGraw',
#  860: 'John McGraw',
#  861: 'Bill Dahlen',
#  862: 'Dan McGann',
#  863: 'Dick Padden',
#  864: 'Jimmy Sheckard',
#  865: 'Lew Drill',
#  866: 'Joe Tinker',
#  867: 'Sam Mertes',
#  868: 'Topsy Hartsel',
#  869: 'Boileryard Clarke',
#  870: 'Kid Gleason',
#  871: 'Bill Donovan',
#  872: 'Bill Donovan',
#  873: 'George Mullin',
#  874: 'Fielder Jones',
#  875: 'Casey Patten',
#  876: 'Dutch Jordan',
#  877: 'Dick Padden',
#  878: 'Bill Dahlen',
#  879: 'Doc Marshall',
#  880: 'Billy Gilbert',
#  881: 'Fred Clarke',
#  882: 'Mike Lynch',
#  883: 'George McBride',
#  884: 'Deacon Phillippe',
#  885: 'Cozy Dolan',
#  886: 'Fielder Jones',
#  887: 'Dan McGann',
#  888: 'Fred Abbott',
#  889: 'Harry Bemis',
#  890: 'Clark Griffith',
#  891: 'John McGraw',
#  892: 'Sammy Strang',
#  893: 'Joe Kelley',
#  894: 'Patsy Dougherty',
#  895: 'Otis Clymer',
#  896: 'Jack Warner',
#  897: 'Jim Jackson',
#  898: 'Admiral Schlei',
#  899: 'Gus Dundon',
#  900: 'Cliff Blankenship',
#  901: 'Otis Clymer',
#  902: 'Clark Griffith',
#  903: 'Joe Kelley',
#  904: 'Red Dooin',
#  905: 'Joe Cassiday',
#  906: 'John McGraw',
#  907: 'John McGraw',
#  908: 'Doc Scanlan',
#  909: 'Jimmy Sheckard',
#  910: 'Boileryard Clarke',
#  911: 'Christy Mathewson',
#  912: 'John McGraw',
#  913: 'Admiral Schlei',
#  914: 'Clark Griffith',
#  915: 'Billy Gilbert',
#  916: 'Fielder Jones',
#  917: 'Bill Hogg',
#  918: 'Jim Jackson',
#  919: 'Jake Stahl',
#  920: 'Miller Huggins',
#  921: 'Sam Leever',
#  922: 'Honus Wagner',
#  923: 'Red Owens',
#  924: 'Jimmy McAleer',
#  925: 'Sam Mertes',
#  926: 'Ducky Holmes',
#  927: 'Jimmy Collins',
#  928: 'George Davis',
#  929: 'Harry Steinfeldt',
#  930: 'Duff Cooley',
#  931: 'Fritz Buelow',
#  932: 'Addie Joss',
#  933: 'Clark Griffith',
#  934: 'Bill Armour',
#  935: 'Germany Schaefer',
#  936: 'Mike Donlin',
#  937: 'Jimmy Sheckard',
#  938: 'Jimmy Burke',
#  939: 'Mike Grady',
#  940: 'Danny Shay',
#  941: 'Bill Armour',
#  942: 'Lew Drill',
#  943: 'Ed Killian',
#  944: 'Jim Jackson',
#  945: 'Dummy Taylor',
#  946: 'Bill Donovan',
#  947: 'Cy Seymour',
#  948: 'Fielder Jones',
#  949: 'Jack Chesbro',
#  950: 'Red Kleinow',
#  951: 'Shad Barry',
#  952: 'Roger Bresnahan',
#  953: 'Bill Dahlen',
#  954: 'John McGraw',
#  955: 'Hugh Duffy',
#  956: 'Joe Kelley',
#  957: 'Chick Fraser',
#  958: 'Ed Abbaticchio',
#  959: 'Fielder Jones',
#  960: 'Chief Bender',
#  961: 'Joe McGinnity',
#  962: 'Sam Leever',
#  963: 'Roger Bresnahan',
#  964: 'Bill Dahlen',
#  965: 'John McGraw',
#  966: 'Duff Cooley',
#  967: 'Red Dooin',
#  968: 'Heinie Peitz',
#  969: 'Otis Clymer',
#  970: 'Patsy Flaherty',
#  971: 'Dan McGann',
#  972: 'Mike Donlin',
#  973: 'Roger Bresnahan',
#  974: 'Ernie Courtney',
#  975: 'Tully Sparks',
#  976: 'Shad Barry',
#  977: 'Monte Cross',
#  978: 'Noodles Hahn',
#  979: 'Kitty Bransfield',
#  980: 'Hugh Duffy',
#  981: 'Jiggs Donahue',
#  982: 'Jimmy Barrett',
#  983: 'Honus Wagner',
#  984: 'Billy Gilbert',
#  985: 'Bob Rhoads',
#  986: 'Dan McGann',
#  987: 'Bill Bradley',
#  988: 'Fritz Buelow',
#  989: 'Jake Stahl',
#  990: 'Fielder Jones',
#  991: 'Kid Elberfeld',
#  992: 'John McGraw',
#  993: 'John McGraw',
#  994: 'Bill Dahlen',
#  995: 'Fred Tenney',
#  996: 'Joe Kelley',
#  997: 'John McGraw',
#  998: 'Jimmy Slagle',
#  999: 'Clark Griffith',
#  ...}

# %%
ejections.EJECTEENAME.value_counts()
# Out:
# EJECTEENAME
# Bobby Cox         165
# John McGraw       139
# Leo Durocher      134
# Frankie Frisch    100
# Earl Weaver        97
#                  ...
# Bill Slayback       1
# Angel Mangual       1
# Dick Billings       1
# Rich Hand           1
# Josh Rojas          1
# Name: count, Length: 4236, dtype: int64

# %%
#ejections[ejections['REASON'].str.contains('doc')]

pmc = ('P' or 'M' or 'C')


player_ejections = ejections[ejections['JOB'] == 'P']
manager_ejections = ejections[ejections['JOB'] == 'M']
coach_ejections = ejections[ejections['JOB'] == 'C']
trainer_ejections = ejections[ejections['JOB'] == 'T']
other_ejections = ejections[ejections['JOB'] == 'N']
#other_ejections.EJECTEENAME.value_counts()
other_ejections
# Out:
#              GAMEID        DATE DH            EJECTEE        EJECTEENAME TEAM  \
# 1414   NYA190807090  07/09/1908      Ink Spot Erasmus   Ink Spot Erasmus  DET
# 3543   NYA192005190  05/19/1920           Unknown fan        Unknown fan  NYA
# 3585   SLN192007210  07/21/1920           Unknown fan        Unknown fan  SLN
# 5572   PHI194207030  07/03/1942           Unknown fan        Unknown fan  PHI
# 5585   CHA194207261  07/26/1942  1   Charlie Comiskey   Charlie Comiskey  CHA
# 7955   CLE196206171  06/17/1962  1  Enrique Izquierdo  Enrique Izquierdo  CLE
# 8501   NYA196606212  06/21/1966  2        Unknown fan        Unknown fan  NYA
# 11232  NYN198405090  05/09/1984           Al Friedman        Al Friedman  NYN
# 11233  NYN198405090  05/09/1984           Doug Zimmer        Doug Zimmer  NYN
# 11280  MIN198406210  06/21/1984           Pat Majeske        Pat Majeske  MIN
# 11388  MON198408290  08/29/1984               Youppi!            Youppi!  MON
# 12276  MON198908230  08/23/1989               Youppi!            Youppi!  MON
# 12920  TOR199305220  05/22/1993            B.J. Birdy         B.J. Birdy  TOR
# 13455  COL199605050  05/05/1996          Mike Wallace       Mike Wallace  FLO
# 14673  CHN200108070  08/07/2001       Steve McMichael    Steve McMichael  CHN
# 16708  MIL201009070  09/07/2010            Sean Ottow         Sean Ottow  MIL
# 17831  PHI201608020  08/02/2016           Unknown fan        Unknown fan  PHI
#
#       JOB    UMPIRE       UMPIRENAME  INNING  \
# 1414    N  sherj901    Jack Sheridan      -1
# 3543    N  owenb901      Brick Owens       2
# 3585    N  klemb901        Bill Klem      11
# 5572    N  stewb901     Bill Stewart       5
# 5585    N  quinj901       John Quinn       8
# 7955    N  hurle901     Eddie Hurley       2
# 8501    N  chyln901    Nestor Chylak       6
# 11232   N  westj901         Joe West       4
# 11233   N  westj901         Joe West       4
# 11280   N  kaisk901       Ken Kaiser       4
# 11388   N  willb901    Bill Williams      -1
# 12276   N  davib902     Bob Davidson      -1
# 12920   N  mckej901       Jim McKean       8
# 13455   N  rungp901       Paul Runge       7
# 14673   N  herna901  Angel Hernandez       7
# 16708   N  davib902     Bob Davidson       7
# 17831   N  davib902     Bob Davidson       6
#
#                                                   REASON
# 1414                            [mascot] bench jockeying
# 3543                              [unknown fan] on field
# 3585                              [unknown fan] rudeness
# 5572                       [unknown fan] throwing bottle
# 5585                     [owner's son] interference call
# 7955   [bullpen catcher] refusing to get bullpen ball...
# 8501               [unknown fan] interfering with player
# 11232           [cameraman] showing replay of close call
# 11233           [cameraman] showing replay of close call
# 11280                   [video operator] tipping pitches
# 11388                                           [mascot]
# 12276                    [mascot] banging on dugout roof
# 12920                [held nose; mascot] catch/trap call
# 13455                     [equipment manager] call at hp
# 14673  [celebrity] threatening the umpires (after sin...
# 16708           [fan] drunken fan heckling yadier molina
# 17831                 [fan] fan using obnoxious language

# %%
extra_innings = ejections[ejections['INNING'] > 9]

extra_innings['INNING'].value_counts()
# Out:
# INNING
# 10    355
# 11    178
# 12     92
# 13     44
# 14     40
# 15     12
# 17      4
# 16      4
# 20      4
# 19      2
# 18      1
# Name: count, dtype: int64

# %%
#standard_innings = ejections[ejections['INNING'] > 0]

standard_innings = ejections[(ejections['INNING'] > 0) & (ejections['INNING'] < 10)]
standard_innings['INNING'].value_counts()
# Out:
# INNING
# 8    2763
# 7    2610
# 6    2280
# 9    2098
# 5    1917
# 4    1688
# 3    1517
# 1    1270
# 2    1129
# Name: count, dtype: int64
